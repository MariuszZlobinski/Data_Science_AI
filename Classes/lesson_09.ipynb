# %%
# # Zadanie 12
# from abc import abstractmethod,ABC

# class Figura(ABC):
#     def __init__(self):
#         pass

#     def oblicz_pole(self):
#         pass

# class Prostokat(Figura):
#     def __init__(self):
#         super().__init__()

#     def oblicz_pole(self):
#         return super().oblicz_pole()
    
# class Koło(Figura):
#     def __init__(self):
#         super().__init__()

#     def oblicz_pole(self):
#         return super().oblicz_pole()
